# %% [markdown]
# # Yahoo Groups message scraper
#
# This notebook provides code that will dowload messages from *private* Yahoo Groups. Another notebook `YahooScra.jpynb` uses [Selenium](http://selenium-python.readthedocs.io/). This notebook uses [reqeusts](http://docs.python-requests.org/en/latest/user/install/).
#
# Another GitHub.com repository ([YahooGroups-Archiver](https://github.com/andrewferguson/YahooGroups-Archiver)) provided guidance related to accessing *private* Yahoo Groups. After logging into the private group you need to provide two pieces of information from the cookies:
#
# > Cookie information can be found through the use of a plug-in for
# > your web browser. (I use 'Cookie Manager' on FireFox, although
# > there are many other options for FireFox and other browsers). The
# > two cookies you are looking for are called Y and T, and they are
# > linked to the domain yahoo.com. Extract the data from these
# > cookies, and paste it into the appropriate variables... a cookie
# > will expire after a certain amount of time, which varies between
# > computers. This means that you may have to re-fetch the Y and T
# > cookie data every few days, or you will not be able to archive
# > private groups. ([YahooGroups-Archiver](https://github.com/andrewferguson/YahooGroups-Archiver))
#
# (Last tested April 21, 2018)

# %%
import pandas as pd
from pandas import Series, DataFrame
from bs4 import BeautifulSoup
import requests
import json
import datetime
import time
import os

# %%
# Get groupname from user.
grp_name = input(prompt='What is the group name you seek to scrape?  ')
# Give grp_name a default if no input.
if grp_name == '':
    grp_name = 'concatenative'
# Out:
# What is the group name you seek to scrape?  studentjudicial

# %%
# These variables will take the cookies from 'Cookie Manager' discussed above as strings.
cookie_T = ''
cookie_Y = ''

# Define a list to log successful attempts.
fetch_log = []

# Iterate through the private group messages. The most recent group message number 
# can be found at: https://groups.yahoo.com/api/v1/groups/<groupname>/messages?count=10
# Parse the results to discern the most recent message number.
for i in range(1737,0,-1):
    fetch_log.append(
        ('{} Working on message {}.'.format(
            str(datetime.datetime.now()), str(i))))
    # For demonstration purposes use a generic groupsuch as 'concatenative'
    
    # Alternate code approach available.
    # s = requests.Session()
    # post = s.get('https://groups.yahoo.com/api/v1/groups/' + grp_name + '/messages/' + str(i) + '/', cookies={'T': cookie_T, 'Y': cookie_Y})

    post = requests.get(
        'https://groups.yahoo.com/api/v1/groups/' + grp_name + '/messages/' + str(i) + '/', 
        cookies={'T': cookie_T, 'Y': cookie_Y})

    # Yahoo Groups api returns JSON.
    post_parsed = json.loads(post.text)
    
    # The api result uses html in the messageBody; remove html tags from messageBody.
    try:
        soup = BeautifulSoup(post_parsed['ygData']['messageBody'], 'html.parser')
        soupstring = soup.get_text()
    # If no message found for that index; populate with message not found.
    except KeyError:
        soupstring = 'Post number {} was not found.'.format(str(i))
    
    # Optionally remove comments from html
    # pullstring = soupstring[soupstring.find('<!--'):soupstring.find('-->')+3]
    # cleanstring = soupstring.replace(pullstring,'')
    # soupstring = cleanstring
    
    # Save the message body as a .txt file.
    post_file = open(
        os.path.join(
            'msgs', ''.join(
                (grp_name + '_' + str(i) + r'_post.txt'))), 'w', encoding='utf-8')
    post_file.write(soupstring)
    post_file.close()
    
    # Save the api result as a .json file.
    json_file = open(
        os.path.join(
            'msgs', ''.join(
                (grp_name + '_' + str(i) + r'_json.json'))), 'w', encoding='utf-8')
    json_file.write(post.text)
    json_file.close()
    
    # Optionally pause to assist in avoiding CAPTCHA and other anti-robot features.
    time.sleep(.1)

# %%
# Save fetch_log for later reference.
with open(grp_name + '_fetch_log_' + 
        str(datetime.datetime.now())[2:16].replace(" ", "-").replace(":","") + 
        '.log', mode='w') as logfile:
            print('This is the log of fetched messages file from {}'.format(
                str(datetime.datetime.now())), file=logfile)
            print('Yahoo Group name {}.'.format(grp_name), file=logfile)
            for fetch_line in fetch_log:
                print(fetch_line, file = logfile)
logfile.close

# %%
# Get location of messages to compile.
folder_location = input(prompt='What is the location of messages (no input will default to msgs)?  ')
# Give grp_name a default if no input.
if folder_location == '':
    folder_location = 'msgs'
# Out:
# What is the location of messages (no input will default to msgs)?

# %%
# Build a dataset from the files created above.

# Define a list to log errors.
error_log  = []

# Define a list to hold structured data.
grandlist = []

# Iterate through the message files.
for i in range(33102,0,-1):
    try:
        work_file = open(
            os.path.join(
                folder_location, grp_name + '_' + str(i) + '_json.json'), 'r', encoding='utf-8')
        work_parse = json.loads(work_file.read())
        
        # Define list to hold current record.
        mylist = []
        mylist = [
            work_parse['ygData']['userId'],
            work_parse['ygData']['authorName'],
            work_parse['ygData']['subject'],
            work_parse['ygData']['postDate'],
            str(datetime.datetime.fromtimestamp(
                int(work_parse['ygData']['postDate'])).strftime('%Y-%m-%d %H:%M:%S')),
            work_parse['ygData']['msgId'],
            work_parse['ygData']['prevInTopic'],
            work_parse['ygData']['nextInTopic'],
            work_parse['ygData']['prevInTime'],
            work_parse['ygData']['nextInTime'],
            work_parse['ygData']['topicId'],
            work_parse['ygData']['numMessagesInTopic'],
            work_parse['ygData']['messageBody']]
        work_file.close()
        
        work_file = open(
            os.path.join(
                folder_location, grp_name + '_' + str(i) + '_post.txt'), 'r', encoding='utf-8')
        mylist.append(work_file.read())
        work_file.close()

        # Add the current observation to the structured data set.
        grandlist.append(mylist)
    except FileNotFoundError:
        # If file not found, provide output and log error.
        print('Message number ' + str(i) + ' - Not found.')
        error_log.append('FileNotFoundError. Message number {}.'.format(str(i)))
    except KeyError:
        # If any of the JSON keys (variables) not found, provide output and log error.
        print('Message number ' + str(i) + ' - KeyError.')
        error_log.append('KeyError. Message number '.format(str(i)))
    except OSError:
        # If OSError, provide output and log error.
        print('Message number ' + str(i) + ' - OSError.')
        error_log.append('OSError. Message number '.format(str(i)))
# Out:
# Message number 33086 - KeyError.
# Message number 32171 - KeyError.
# Message number 31976 - KeyError.
# Message number 31891 - KeyError.
# Message number 31373 - KeyError.
# Message number 31002 - KeyError.
# Message number 30761 - KeyError.
# Message number 30710 - KeyError.
# Message number 30575 - KeyError.
# Message number 29483 - KeyError.
# Message number 29460 - KeyError.
# Message number 29015 - KeyError.
# Message number 28586 - KeyError.
# Message number 27679 - KeyError.
# Message number 27097 - KeyError.
# Message number 27014 - KeyError.
# Message number 27007 - KeyError.
# Message number 26995 - KeyError.
# Message number 26625 - KeyError.
# Message number 26624 - KeyError.
# Message number 25492 - KeyError.
# Message number 25227 - KeyError.
# Message number 24592 - KeyError.
# Message number 23643 - KeyError.
# Message number 22883 - KeyError.
# Message number 22632 - KeyError.
# Message number 22438 - KeyError.
# Message number 22437 - KeyError.
# Message number 22283 - KeyError.
# Message number 22257 - KeyError.
# Message number 22256 - KeyError.
# Message number 22255 - KeyError.
# Message number 22254 - KeyError.
# Message number 22253 - KeyError.
# Message number 22252 - KeyError.
# Message number 22251 - KeyError.
# Message number 22250 - KeyError.
# Message number 22249 - KeyError.
# Message number 22248 - KeyError.
# Message number 22247 - KeyError.
# Message number 22246 - KeyError.
# Message number 22245 - KeyError.
# Message number 22244 - KeyError.
# Message number 22243 - KeyError.
# Message number 22242 - KeyError.
# Message number 22241 - KeyError.
# Message number 22240 - KeyError.
# Message number 22239 - KeyError.
# Message number 22238 - KeyError.
# Message number 22237 - KeyError.
# Message number 22236 - KeyError.
# Message number 22235 - KeyError.
# Message number 22234 - KeyError.
# Message number 22233 - KeyError.
# Message number 22232 - KeyError.
# Message number 22231 - KeyError.
# Message number 22230 - KeyError.
# Message number 22229 - KeyError.
# Message number 22228 - KeyError.
# Message number 22227 - KeyError.
# Message number 22226 - KeyError.
# Message number 22225 - KeyError.
# Message number 22224 - KeyError.
# Message number 22223 - KeyError.
# Message number 22222 - KeyError.
# Message number 22221 - KeyError.
# Message number 22220 - KeyError.
# Message number 22219 - KeyError.
# Message number 22218 - KeyError.
# Message number 22217 - KeyError.
# Message number 22216 - KeyError.
# Message number 22215 - KeyError.
# Message number 22214 - KeyError.
# Message number 22213 - KeyError.
# Message number 22212 - KeyError.
# Message number 22211 - KeyError.
# Message number 22210 - KeyError.
# Message number 22209 - KeyError.
# Message number 22208 - KeyError.
# Message number 22207 - KeyError.
# Message number 22206 - KeyError.
# Message number 22205 - KeyError.
# Message number 22204 - KeyError.
# Message number 22203 - KeyError.
# Message number 22202 - KeyError.
# Message number 22201 - KeyError.
# Message number 22200 - KeyError.
# Message number 22199 - KeyError.
# Message number 22198 - KeyError.
# Message number 22197 - KeyError.
# Message number 22196 - KeyError.
# Message number 22195 - KeyError.
# Message number 22194 - KeyError.
# Message number 22193 - KeyError.
# Message number 22192 - KeyError.
# Message number 22191 - KeyError.
# Message number 22190 - KeyError.
# Message number 22189 - KeyError.
# Message number 22188 - KeyError.
# Message number 22187 - KeyError.
# Message number 22186 - KeyError.
# Message number 22185 - KeyError.
# Message number 22184 - KeyError.
# Message number 22183 - KeyError.
# Message number 22182 - KeyError.
# Message number 22181 - KeyError.
# Message number 22180 - KeyError.
# Message number 22179 - KeyError.
# Message number 22178 - KeyError.
# Message number 22177 - KeyError.
# Message number 22176 - KeyError.
# Message number 22175 - KeyError.
# Message number 22012 - KeyError.
# Message number 22011 - KeyError.
# Message number 22010 - KeyError.
# Message number 22009 - KeyError.
# Message number 22008 - KeyError.
# Message number 22007 - KeyError.
# Message number 22006 - KeyError.
# Message number 22005 - KeyError.
# Message number 22004 - KeyError.
# Message number 22003 - KeyError.
# Message number 22002 - KeyError.
# Message number 22001 - KeyError.
# Message number 22000 - KeyError.
# Message number 21999 - KeyError.
# Message number 21998 - KeyError.
# Message number 21997 - KeyError.
# Message number 21996 - KeyError.
# Message number 21995 - KeyError.
# Message number 21994 - KeyError.
# Message number 21993 - KeyError.
# Message number 21992 - KeyError.
# Message number 21991 - KeyError.
# Message number 21990 - KeyError.
# Message number 21989 - KeyError.
# Message number 21988 - KeyError.
# Message number 21987 - KeyError.
# Message number 21986 - KeyError.
# Message number 21985 - KeyError.
# Message number 21984 - KeyError.
# Message number 21983 - KeyError.
# Message number 21242 - KeyError.
# Message number 21061 - KeyError.
# Message number 20279 - KeyError.
# Message number 20031 - KeyError.
# Message number 19851 - KeyError.
# Message number 17972 - KeyError.
# Message number 17935 - KeyError.
# Message number 17742 - KeyError.
# Message number 17499 - KeyError.
# Message number 16146 - KeyError.
# Message number 16086 - KeyError.
# Message number 16083 - KeyError.
# Message number 15120 - KeyError.
# Message number 14740 - KeyError.
# Message number 14623 - KeyError.
# Message number 13192 - KeyError.
# Message number 12575 - KeyError.
# Message number 12500 - KeyError.
# Message number 12090 - KeyError.
# Message number 11827 - KeyError.
# Message number 11302 - KeyError.
# Message number 11278 - KeyError.
# Message number 11277 - KeyError.
# Message number 10871 - KeyError.
# Message number 10745 - KeyError.
# Message number 10744 - KeyError.
# Message number 10743 - KeyError.
# Message number 10629 - KeyError.
# Message number 10471 - KeyError.
# Message number 10464 - KeyError.
# Message number 10299 - KeyError.
# Message number 10297 - KeyError.
# Message number 10207 - KeyError.
# Message number 10204 - KeyError.
# Message number 10185 - KeyError.
# Message number 10177 - KeyError.
# Message number 10141 - KeyError.
# Message number 10108 - KeyError.
# Message number 10106 - KeyError.
# Message number 10076 - KeyError.
# Message number 10074 - KeyError.
# Message number 10072 - KeyError.
# Message number 10012 - KeyError.
# Message number 9989 - KeyError.
# Message number 9968 - KeyError.
# Message number 9942 - KeyError.
# Message number 9929 - KeyError.
# Message number 9915 - KeyError.
# Message number 9905 - KeyError.
# Message number 9904 - KeyError.
# Message number 9903 - KeyError.
# Message number 9902 - KeyError.
# Message number 9880 - KeyError.
# Message number 9868 - KeyError.
# Message number 9866 - KeyError.
# Message number 9812 - KeyError.
# Message number 9805 - KeyError.
# Message number 9727 - KeyError.
# Message number 9702 - KeyError.
# Message number 9659 - KeyError.
# Message number 9655 - KeyError.
# Message number 9653 - KeyError.
# Message number 9634 - KeyError.
# Message number 9618 - KeyError.
# Message number 9616 - KeyError.
# Message number 9595 - KeyError.
# Message number 9594 - KeyError.
# Message number 9589 - KeyError.
# Message number 9584 - KeyError.
# Message number 9557 - KeyError.
# Message number 9538 - KeyError.
# Message number 9537 - KeyError.
# Message number 9525 - KeyError.
# Message number 9466 - KeyError.
# Message number 9463 - KeyError.
# Message number 9453 - KeyError.
# Message number 9452 - KeyError.
# Message number 9431 - KeyError.
# Message number 9419 - KeyError.
# Message number 9402 - KeyError.
# Message number 9363 - KeyError.
# Message number 9362 - KeyError.
# Message number 9361 - KeyError.
# Message number 9360 - KeyError.
# Message number 9359 - KeyError.
# Message number 9358 - KeyError.
# Message number 9357 - KeyError.
# Message number 9355 - KeyError.
# Message number 9353 - KeyError.
# Message number 9343 - KeyError.
# Message number 9332 - KeyError.
# Message number 9331 - KeyError.
# Message number 9328 - KeyError.
# Message number 9239 - KeyError.
# Message number 9236 - KeyError.
# Message number 9235 - KeyError.
# Message number 9224 - KeyError.
# Message number 9223 - KeyError.
# Message number 9221 - KeyError.
# Message number 9220 - KeyError.
# Message number 9218 - KeyError.
# Message number 9199 - KeyError.
# Message number 9184 - KeyError.
# Message number 9183 - KeyError.
# Message number 9165 - KeyError.
# Message number 9164 - KeyError.
# Message number 9142 - KeyError.
# Message number 9137 - KeyError.
# Message number 9114 - KeyError.
# Message number 9048 - KeyError.
# Message number 9046 - KeyError.
# Message number 9045 - KeyError.
# Message number 9044 - KeyError.
# Message number 9035 - KeyError.
# Message number 8988 - KeyError.
# Message number 8972 - KeyError.
# Message number 8965 - KeyError.
# Message number 8964 - KeyError.
# Message number 8963 - KeyError.
# Message number 8888 - KeyError.
# Message number 8872 - KeyError.
# Message number 8871 - KeyError.
# Message number 8864 - KeyError.
# Message number 8863 - KeyError.
# Message number 8862 - KeyError.
# Message number 8858 - KeyError.
# Message number 8851 - KeyError.
# Message number 8845 - KeyError.
# Message number 8844 - KeyError.
# Message number 8839 - KeyError.
# Message number 8835 - KeyError.
# Message number 8830 - KeyError.
# Message number 8829 - KeyError.
# Message number 8810 - KeyError.
# Message number 8809 - KeyError.
# Message number 8800 - KeyError.
# Message number 8797 - KeyError.
# Message number 8791 - KeyError.
# Message number 8788 - KeyError.
# Message number 8721 - KeyError.
# Message number 8718 - KeyError.
# Message number 8716 - KeyError.
# Message number 8715 - KeyError.
# Message number 8666 - KeyError.
# Message number 8662 - KeyError.
# Message number 8625 - KeyError.
# Message number 8614 - KeyError.
# Message number 8613 - KeyError.
# Message number 8612 - KeyError.
# Message number 8611 - KeyError.
# Message number 8610 - KeyError.
# Message number 8607 - KeyError.
# Message number 8606 - KeyError.
# Message number 8604 - KeyError.
# Message number 8595 - KeyError.
# Message number 8594 - KeyError.
# Message number 8593 - KeyError.
# Message number 8580 - KeyError.
# Message number 8578 - KeyError.
# Message number 8561 - KeyError.
# Message number 8560 - KeyError.
# Message number 8555 - KeyError.
# Message number 8554 - KeyError.
# Message number 8553 - KeyError.
# Message number 8546 - KeyError.
# Message number 8545 - KeyError.
# Message number 8544 - KeyError.
# Message number 8543 - KeyError.
# Message number 8542 - KeyError.
# Message number 8444 - KeyError.
# Message number 8443 - KeyError.
# Message number 8442 - KeyError.
# Message number 8436 - KeyError.
# Message number 8432 - KeyError.
# Message number 8425 - KeyError.
# Message number 8424 - KeyError.
# Message number 8423 - KeyError.
# Message number 8422 - KeyError.
# Message number 8421 - KeyError.
# Message number 8420 - KeyError.
# Message number 8419 - KeyError.
# Message number 8418 - KeyError.
# Message number 8381 - KeyError.
# Message number 8355 - KeyError.
# Message number 8352 - KeyError.
# Message number 8343 - KeyError.
# Message number 8342 - KeyError.
# Message number 8332 - KeyError.
# Message number 8289 - KeyError.
# Message number 8279 - KeyError.
# Message number 8276 - KeyError.
# Message number 8225 - KeyError.
# Message number 8213 - KeyError.
# Message number 8153 - KeyError.
# Message number 8152 - KeyError.
# Message number 8138 - KeyError.
# Message number 8132 - KeyError.
# Message number 8089 - KeyError.
# Message number 8084 - KeyError.
# Message number 8083 - KeyError.
# Message number 8045 - KeyError.
# Message number 8043 - KeyError.
# Message number 8042 - KeyError.
# Message number 8035 - KeyError.
# Message number 8034 - KeyError.
# Message number 8022 - KeyError.
# Message number 8021 - KeyError.
# Message number 7947 - KeyError.
# Message number 7937 - KeyError.
# Message number 7936 - KeyError.
# Message number 7932 - KeyError.
# Message number 7931 - KeyError.
# Message number 7930 - KeyError.
# Message number 7881 - KeyError.
# Message number 7879 - KeyError.
# Message number 7865 - KeyError.
# Message number 7864 - KeyError.
# Message number 7833 - KeyError.
# Message number 7828 - KeyError.
# Message number 7824 - KeyError.
# Message number 7822 - KeyError.
# Message number 7820 - KeyError.
# Message number 7811 - KeyError.
# Message number 7802 - KeyError.
# Message number 7801 - KeyError.
# Message number 7783 - KeyError.
# Message number 7775 - KeyError.
# Message number 7771 - KeyError.
# Message number 7770 - KeyError.
# Message number 7769 - KeyError.
# Message number 7764 - KeyError.
# Message number 7763 - KeyError.
# Message number 7741 - KeyError.
# Message number 7710 - KeyError.
# Message number 7708 - KeyError.
# Message number 7690 - KeyError.
# Message number 7681 - KeyError.
# Message number 7680 - KeyError.
# Message number 7669 - KeyError.
# Message number 7655 - KeyError.
# Message number 7654 - KeyError.
# Message number 7649 - KeyError.
# Message number 7608 - KeyError.
# Message number 7607 - KeyError.
# Message number 7603 - KeyError.
# Message number 7568 - KeyError.
# Message number 7567 - KeyError.
# Message number 7566 - KeyError.
# Message number 7365 - KeyError.
# Message number 7364 - KeyError.
# Message number 7301 - KeyError.
# Message number 7275 - KeyError.
# Message number 7242 - KeyError.
# Message number 7229 - KeyError.
# Message number 7215 - KeyError.
# Message number 7198 - KeyError.
# Message number 7196 - KeyError.
# Message number 7195 - KeyError.
# Message number 7175 - KeyError.
# Message number 7174 - KeyError.
# Message number 7173 - KeyError.
# Message number 7170 - KeyError.
# Message number 7168 - KeyError.
# Message number 7165 - KeyError.
# Message number 7164 - KeyError.
# Message number 7163 - KeyError.
# Message number 7162 - KeyError.
# Message number 7161 - KeyError.
# Message number 7160 - KeyError.
# Message number 7159 - KeyError.
# Message number 7157 - KeyError.
# Message number 7114 - KeyError.
# Message number 7113 - KeyError.
# Message number 7112 - KeyError.
# Message number 7111 - KeyError.
# Message number 7108 - KeyError.
# Message number 7105 - KeyError.
# Message number 7101 - KeyError.
# Message number 7082 - KeyError.
# Message number 7050 - KeyError.
# Message number 7041 - KeyError.
# Message number 7034 - KeyError.
# Message number 7027 - KeyError.
# Message number 7000 - KeyError.
# Message number 6999 - KeyError.
# Message number 6994 - KeyError.
# Message number 6993 - KeyError.
# Message number 6969 - KeyError.
# Message number 6965 - KeyError.
# Message number 6963 - KeyError.
# Message number 6961 - KeyError.
# Message number 6951 - KeyError.
# Message number 6950 - KeyError.
# Message number 6936 - KeyError.
# Message number 6924 - KeyError.
# Message number 6923 - KeyError.
# Message number 6922 - KeyError.
# Message number 6921 - KeyError.
# Message number 6888 - KeyError.
# Message number 6885 - KeyError.
# Message number 6847 - KeyError.
# Message number 6846 - KeyError.
# Message number 6810 - KeyError.
# Message number 6809 - KeyError.
# Message number 6777 - KeyError.
# Message number 6764 - KeyError.
# Message number 6763 - KeyError.
# Message number 6758 - KeyError.
# Message number 6748 - KeyError.
# Message number 6746 - KeyError.
# Message number 6728 - KeyError.
# Message number 6716 - KeyError.
# Message number 6715 - KeyError.
# Message number 6714 - KeyError.
# Message number 6705 - KeyError.
# Message number 6696 - KeyError.
# Message number 6682 - KeyError.
# Message number 6600 - KeyError.
# Message number 6574 - KeyError.
# Message number 6569 - KeyError.
# Message number 6561 - KeyError.
# Message number 6513 - KeyError.
# Message number 6509 - KeyError.
# Message number 6456 - KeyError.
# Message number 6409 - KeyError.
# Message number 6368 - KeyError.
# Message number 6359 - KeyError.
# Message number 6328 - KeyError.
# Message number 6316 - KeyError.
# Message number 6304 - KeyError.
# Message number 6299 - KeyError.
# Message number 6292 - KeyError.
# Message number 6290 - KeyError.
# Message number 6287 - KeyError.
# Message number 6286 - KeyError.
# Message number 6285 - KeyError.
# Message number 6284 - KeyError.
# Message number 6283 - KeyError.
# Message number 6282 - KeyError.
# Message number 6280 - KeyError.
# Message number 6279 - KeyError.
# Message number 6278 - KeyError.
# Message number 6258 - KeyError.
# Message number 6257 - KeyError.
# Message number 6255 - KeyError.
# Message number 6250 - KeyError.
# Message number 6242 - KeyError.
# Message number 6230 - KeyError.
# Message number 6229 - KeyError.
# Message number 6228 - KeyError.
# Message number 6226 - KeyError.
# Message number 6167 - KeyError.
# Message number 6107 - KeyError.
# Message number 6104 - KeyError.
# Message number 6098 - KeyError.
# Message number 6053 - KeyError.
# Message number 6042 - KeyError.
# Message number 6030 - KeyError.
# Message number 6017 - KeyError.
# Message number 5944 - KeyError.
# Message number 5943 - KeyError.
# Message number 5919 - KeyError.
# Message number 5903 - KeyError.
# Message number 5792 - KeyError.
# Message number 5791 - KeyError.
# Message number 5763 - KeyError.
# Message number 5753 - KeyError.
# Message number 5691 - KeyError.
# Message number 5685 - KeyError.
# Message number 5624 - KeyError.
# Message number 5618 - KeyError.
# Message number 5581 - KeyError.
# Message number 5577 - KeyError.
# Message number 5569 - KeyError.
# Message number 5568 - KeyError.
# Message number 5567 - KeyError.
# Message number 5565 - KeyError.
# Message number 5483 - KeyError.
# Message number 5470 - KeyError.
# Message number 5449 - KeyError.
# Message number 5410 - KeyError.
# Message number 5348 - KeyError.
# Message number 5316 - KeyError.
# Message number 5313 - KeyError.
# Message number 5291 - KeyError.
# Message number 5288 - KeyError.
# Message number 5269 - KeyError.
# Message number 5241 - KeyError.
# Message number 5195 - KeyError.
# Message number 5181 - KeyError.
# Message number 5169 - KeyError.
# Message number 5158 - KeyError.
# Message number 5154 - KeyError.
# Message number 5152 - KeyError.
# Message number 5131 - KeyError.
# Message number 5103 - KeyError.
# Message number 5046 - KeyError.
# Message number 5042 - KeyError.
# Message number 5035 - KeyError.
# Message number 5002 - KeyError.
# Message number 4998 - KeyError.
# Message number 4976 - KeyError.
# Message number 4964 - KeyError.
# Message number 4927 - KeyError.
# Message number 4907 - KeyError.
# Message number 4878 - KeyError.
# Message number 4876 - KeyError.
# Message number 4875 - KeyError.
# Message number 4845 - KeyError.
# Message number 4844 - KeyError.
# Message number 4802 - KeyError.
# Message number 4788 - KeyError.
# Message number 4781 - KeyError.
# Message number 4780 - KeyError.
# Message number 4775 - KeyError.
# Message number 4773 - KeyError.
# Message number 4771 - KeyError.
# Message number 4770 - KeyError.
# Message number 4769 - KeyError.
# Message number 4768 - KeyError.
# Message number 4767 - KeyError.
# Message number 4766 - KeyError.
# Message number 4765 - KeyError.
# Message number 4720 - KeyError.
# Message number 4715 - KeyError.
# Message number 4714 - KeyError.
# Message number 4679 - KeyError.
# Message number 4677 - KeyError.
# Message number 4670 - KeyError.
# Message number 4663 - KeyError.
# Message number 4615 - KeyError.
# Message number 4613 - KeyError.
# Message number 4586 - KeyError.
# Message number 4583 - KeyError.
# Message number 4528 - KeyError.
# Message number 4512 - KeyError.
# Message number 4508 - KeyError.
# Message number 4507 - KeyError.
# Message number 4506 - KeyError.
# Message number 4505 - KeyError.
# Message number 4495 - KeyError.
# Message number 4475 - KeyError.
# Message number 4469 - KeyError.
# Message number 4459 - KeyError.
# Message number 4415 - KeyError.
# Message number 4413 - KeyError.
# Message number 4396 - KeyError.
# Message number 4350 - KeyError.
# Message number 4345 - KeyError.
# Message number 4336 - KeyError.
# Message number 4274 - KeyError.
# Message number 4267 - KeyError.
# Message number 4205 - KeyError.
# Message number 3846 - KeyError.
# Message number 3810 - KeyError.
# Message number 3775 - KeyError.
# Message number 3674 - KeyError.
# Message number 3645 - KeyError.
# Message number 3631 - KeyError.
# Message number 3576 - KeyError.
# Message number 3569 - KeyError.
# Message number 3557 - KeyError.
# Message number 3548 - KeyError.
# Message number 3543 - KeyError.
# Message number 3518 - KeyError.
# Message number 3516 - KeyError.
# Message number 3509 - KeyError.
# Message number 3505 - KeyError.
# Message number 3494 - KeyError.
# Message number 3493 - KeyError.
# Message number 3461 - KeyError.
# Message number 3433 - KeyError.
# Message number 3430 - KeyError.
# Message number 3427 - KeyError.
# Message number 3387 - KeyError.
# Message number 3381 - KeyError.
# Message number 3376 - KeyError.
# Message number 3349 - KeyError.
# Message number 3265 - KeyError.
# Message number 3264 - KeyError.
# Message number 3259 - KeyError.
# Message number 3258 - KeyError.
# Message number 3238 - KeyError.
# Message number 3176 - KeyError.
# Message number 3152 - KeyError.
# Message number 3071 - KeyError.
# Message number 3051 - KeyError.
# Message number 2998 - KeyError.
# Message number 2979 - KeyError.
# Message number 2974 - KeyError.
# Message number 2972 - KeyError.
# Message number 2967 - KeyError.
# Message number 2966 - KeyError.
# Message number 2949 - KeyError.
# Message number 2929 - KeyError.
# Message number 2919 - KeyError.
# Message number 2907 - KeyError.
# Message number 2897 - KeyError.
# Message number 2894 - KeyError.
# Message number 2888 - KeyError.
# Message number 2850 - KeyError.
# Message number 2849 - KeyError.
# Message number 2848 - KeyError.
# Message number 2843 - KeyError.
# Message number 2842 - KeyError.
# Message number 2798 - KeyError.
# Message number 2759 - KeyError.
# Message number 2726 - KeyError.
# Message number 2725 - KeyError.
# Message number 2724 - KeyError.
# Message number 2719 - KeyError.
# Message number 2704 - KeyError.
# Message number 2689 - KeyError.
# Message number 2652 - KeyError.
# Message number 2649 - KeyError.
# Message number 2648 - KeyError.
# Message number 2639 - KeyError.
# Message number 2637 - KeyError.
# Message number 2635 - KeyError.
# Message number 2634 - KeyError.
# Message number 2630 - KeyError.
# Message number 2599 - KeyError.
# Message number 2592 - KeyError.
# Message number 2583 - KeyError.
# Message number 2557 - KeyError.
# Message number 2556 - KeyError.
# Message number 2555 - KeyError.
# Message number 2553 - KeyError.
# Message number 2548 - KeyError.
# Message number 2544 - KeyError.
# Message number 2539 - KeyError.
# Message number 2532 - KeyError.
# Message number 2523 - KeyError.
# Message number 2521 - KeyError.
# Message number 2520 - KeyError.
# Message number 2519 - KeyError.
# Message number 2518 - KeyError.
# Message number 2517 - KeyError.
# Message number 2516 - KeyError.
# Message number 2429 - KeyError.
# Message number 2376 - KeyError.
# Message number 2349 - KeyError.
# Message number 2333 - KeyError.
# Message number 2320 - KeyError.
# Message number 2303 - KeyError.
# Message number 2271 - KeyError.
# Message number 2264 - KeyError.
# Message number 2227 - KeyError.
# Message number 2221 - KeyError.
# Message number 2211 - KeyError.
# Message number 2198 - KeyError.
# Message number 2002 - KeyError.
# Message number 1997 - KeyError.
# Message number 1996 - KeyError.
# Message number 1995 - KeyError.
# Message number 1994 - KeyError.
# Message number 1993 - KeyError.
# Message number 1992 - KeyError.
# Message number 1991 - KeyError.
# Message number 1990 - KeyError.
# Message number 1989 - KeyError.
# Message number 1988 - KeyError.
# Message number 1987 - KeyError.
# Message number 1986 - KeyError.
# Message number 1984 - KeyError.
# Message number 1982 - KeyError.
# Message number 1981 - KeyError.
# Message number 1980 - KeyError.
# Message number 1979 - KeyError.
# Message number 1978 - KeyError.
# Message number 1977 - KeyError.
# Message number 1976 - KeyError.
# Message number 1975 - KeyError.
# Message number 1974 - KeyError.
# Message number 1973 - KeyError.
# Message number 1972 - KeyError.
# Message number 1971 - KeyError.
# Message number 1970 - KeyError.
# Message number 1969 - KeyError.
# Message number 1968 - KeyError.
# Message number 1967 - KeyError.
# Message number 1966 - KeyError.
# Message number 1965 - KeyError.
# Message number 1964 - KeyError.
# Message number 1963 - KeyError.
# Message number 1962 - KeyError.
# Message number 1961 - KeyError.
# Message number 1960 - KeyError.
# Message number 1959 - KeyError.
# Message number 1958 - KeyError.
# Message number 1957 - KeyError.
# Message number 1956 - KeyError.
# Message number 1955 - KeyError.
# Message number 1954 - KeyError.
# Message number 1953 - KeyError.
# Message number 1952 - KeyError.
# Message number 1951 - KeyError.
# Message number 1950 - KeyError.
# Message number 1949 - KeyError.
# Message number 1948 - KeyError.
# Message number 1947 - KeyError.
# Message number 1946 - KeyError.
# Message number 1945 - KeyError.
# Message number 1944 - KeyError.
# Message number 1943 - KeyError.
# Message number 1942 - KeyError.
# Message number 1941 - KeyError.
# Message number 1940 - KeyError.
# Message number 1938 - KeyError.
# Message number 1937 - KeyError.
# Message number 1936 - KeyError.
# Message number 1935 - KeyError.
# Message number 1934 - KeyError.
# Message number 1933 - KeyError.
# Message number 1932 - KeyError.
# Message number 1931 - KeyError.
# Message number 1930 - KeyError.
# Message number 1928 - KeyError.
# Message number 1927 - KeyError.
# Message number 1926 - KeyError.
# Message number 1925 - KeyError.
# Message number 1924 - KeyError.
# Message number 1923 - KeyError.
# Message number 1922 - KeyError.
# Message number 1921 - KeyError.
# Message number 1920 - KeyError.
# Message number 1919 - KeyError.
# Message number 1918 - KeyError.
# Message number 1917 - KeyError.
# Message number 1916 - KeyError.
# Message number 1915 - KeyError.
# Message number 1914 - KeyError.
# Message number 1912 - KeyError.
# Message number 1911 - KeyError.
# Message number 1910 - KeyError.
# Message number 1909 - KeyError.
# Message number 1908 - KeyError.
# Message number 1907 - KeyError.
# Message number 1905 - KeyError.
# Message number 1904 - KeyError.
# Message number 1903 - KeyError.
# Message number 1902 - KeyError.
# Message number 1901 - KeyError.
# Message number 1900 - KeyError.
# Message number 1899 - KeyError.
# Message number 1897 - KeyError.
# Message number 1896 - KeyError.
# Message number 1895 - KeyError.
# Message number 1894 - KeyError.
# Message number 1893 - KeyError.
# Message number 1892 - KeyError.
# Message number 1891 - KeyError.
# Message number 1890 - KeyError.
# Message number 1889 - KeyError.
# Message number 1888 - KeyError.
# Message number 1886 - KeyError.
# Message number 1885 - KeyError.
# Message number 1883 - KeyError.
# Message number 1882 - KeyError.
# Message number 1881 - KeyError.
# Message number 1879 - KeyError.
# Message number 1877 - KeyError.
# Message number 1876 - KeyError.
# Message number 1875 - KeyError.
# Message number 1874 - KeyError.
# Message number 1872 - KeyError.
# Message number 1852 - KeyError.
# Message number 1783 - KeyError.
# Message number 1732 - KeyError.
# Message number 1658 - KeyError.
# Message number 1650 - KeyError.
# Message number 1638 - KeyError.
# Message number 1556 - KeyError.
# Message number 1498 - KeyError.
# Message number 1463 - KeyError.
# Message number 1462 - KeyError.
# Message number 1386 - KeyError.
# Message number 1377 - KeyError.
# Message number 1365 - KeyError.
# Message number 1338 - KeyError.
# Message number 1308 - KeyError.
# Message number 1299 - KeyError.
# Message number 1285 - KeyError.
# Message number 1284 - KeyError.
# Message number 1245 - KeyError.
# Message number 1244 - KeyError.
# Message number 1125 - KeyError.
# Message number 1096 - KeyError.
# Message number 1086 - KeyError.
# Message number 1085 - KeyError.
# Message number 1083 - KeyError.
# Message number 1078 - KeyError.
# Message number 1077 - KeyError.
# Message number 1075 - KeyError.
# Message number 1074 - KeyError.
# Message number 1073 - KeyError.
# Message number 1061 - KeyError.
# Message number 1052 - KeyError.
# Message number 1030 - KeyError.
# Message number 1024 - KeyError.
# Message number 1022 - KeyError.
# Message number 1019 - KeyError.
# Message number 1013 - KeyError.
# Message number 1012 - KeyError.
# Message number 995 - KeyError.
# Message number 977 - KeyError.
# Message number 976 - KeyError.
# Message number 966 - KeyError.
# Message number 965 - KeyError.
# Message number 964 - KeyError.
# Message number 963 - KeyError.
# Message number 952 - KeyError.
# Message number 944 - KeyError.
# Message number 932 - KeyError.
# Message number 890 - KeyError.
# Message number 889 - KeyError.
# Message number 879 - KeyError.
# Message number 876 - KeyError.
# Message number 875 - KeyError.
# Message number 873 - KeyError.
# Message number 862 - KeyError.
# Message number 849 - KeyError.
# Message number 840 - KeyError.
# Message number 834 - KeyError.
# Message number 832 - KeyError.
# Message number 831 - KeyError.
# Message number 830 - KeyError.
# Message number 821 - KeyError.
# Message number 820 - KeyError.
# Message number 814 - KeyError.
# Message number 791 - KeyError.
# Message number 781 - KeyError.
# Message number 738 - KeyError.
# Message number 659 - KeyError.
# Message number 608 - KeyError.
# Message number 512 - KeyError.
# Message number 511 - KeyError.
# Message number 509 - KeyError.
# Message number 502 - KeyError.
# Message number 498 - KeyError.
# Message number 497 - KeyError.
# Message number 494 - KeyError.
# Message number 493 - KeyError.
# Message number 488 - KeyError.
# Message number 471 - KeyError.
# Message number 462 - KeyError.
# Message number 456 - KeyError.
# Message number 455 - KeyError.
# Message number 429 - KeyError.
# Message number 412 - KeyError.
# Message number 406 - KeyError.
# Message number 401 - KeyError.
# Message number 400 - KeyError.
# Message number 398 - KeyError.
# Message number 397 - KeyError.
# Message number 396 - KeyError.
# Message number 374 - KeyError.
# Message number 371 - KeyError.
# Message number 353 - KeyError.
# Message number 346 - KeyError.
# Message number 283 - KeyError.
# Message number 241 - KeyError.
# Message number 240 - KeyError.
# Message number 239 - KeyError.
# Message number 238 - KeyError.
# Message number 237 - KeyError.
# Message number 236 - KeyError.
# Message number 235 - KeyError.
# Message number 234 - KeyError.
# Message number 233 - KeyError.
# Message number 232 - KeyError.
# Message number 231 - KeyError.
# Message number 230 - KeyError.
# Message number 229 - KeyError.
# Message number 228 - KeyError.
# Message number 227 - KeyError.
# Message number 226 - KeyError.
# Message number 225 - KeyError.
# Message number 224 - KeyError.
# Message number 223 - KeyError.
# Message number 222 - KeyError.
# Message number 221 - KeyError.
# Message number 220 - KeyError.
# Message number 219 - KeyError.
# Message number 218 - KeyError.
# Message number 217 - KeyError.
# Message number 216 - KeyError.
# Message number 215 - KeyError.
# Message number 214 - KeyError.
# Message number 213 - KeyError.
# Message number 212 - KeyError.
# Message number 211 - KeyError.
# Message number 210 - KeyError.
# Message number 209 - KeyError.
# Message number 208 - KeyError.
# Message number 207 - KeyError.
# Message number 206 - KeyError.
# Message number 205 - KeyError.
# Message number 204 - KeyError.
# Message number 203 - KeyError.
# Message number 202 - KeyError.
# Message number 201 - KeyError.
# Message number 200 - KeyError.
# Message number 199 - KeyError.
# Message number 198 - KeyError.
# Message number 197 - KeyError.
# Message number 196 - KeyError.
# Message number 195 - KeyError.
# Message number 194 - KeyError.
# Message number 193 - KeyError.
# Message number 192 - KeyError.
# Message number 191 - KeyError.
# Message number 190 - KeyError.
# Message number 189 - KeyError.
# Message number 188 - KeyError.
# Message number 187 - KeyError.
# Message number 186 - KeyError.
# Message number 185 - KeyError.
# Message number 184 - KeyError.
# Message number 183 - KeyError.
# Message number 182 - KeyError.
# Message number 181 - KeyError.
# Message number 180 - KeyError.
# Message number 179 - KeyError.
# Message number 178 - KeyError.
# Message number 177 - KeyError.
# Message number 176 - KeyError.
# Message number 175 - KeyError.
# Message number 174 - KeyError.
# Message number 173 - KeyError.
# Message number 172 - KeyError.
# Message number 171 - KeyError.
# Message number 170 - KeyError.
# Message number 169 - KeyError.
# Message number 168 - KeyError.
# Message number 167 - KeyError.
# Message number 166 - KeyError.
# Message number 165 - KeyError.
# Message number 164 - KeyError.
# Message number 163 - KeyError.
# Message number 162 - KeyError.
# Message number 161 - KeyError.
# Message number 160 - KeyError.
# Message number 159 - KeyError.
# Message number 158 - KeyError.
# Message number 157 - KeyError.
# Message number 156 - KeyError.
# Message number 155 - KeyError.
# Message number 154 - KeyError.
# Message number 153 - KeyError.
# Message number 152 - KeyError.
# Message number 151 - KeyError.
# Message number 150 - KeyError.
# Message number 149 - KeyError.
# Message number 148 - KeyError.
# Message number 147 - KeyError.
# Message number 146 - KeyError.
# Message number 145 - KeyError.
# Message number 144 - KeyError.
# Message number 143 - KeyError.
# Message number 142 - KeyError.
# Message number 141 - KeyError.
# Message number 140 - KeyError.
# Message number 139 - KeyError.
# Message number 138 - KeyError.
# Message number 137 - KeyError.
# Message number 136 - KeyError.
# Message number 135 - KeyError.
# Message number 134 - KeyError.
# Message number 133 - KeyError.
# Message number 132 - KeyError.
# Message number 131 - KeyError.
# Message number 130 - KeyError.
# Message number 129 - KeyError.
# Message number 128 - KeyError.
# Message number 127 - KeyError.
# Message number 126 - KeyError.
# Message number 125 - KeyError.
# Message number 124 - KeyError.
# Message number 123 - KeyError.
# Message number 122 - KeyError.
# Message number 121 - KeyError.
# Message number 120 - KeyError.
# Message number 119 - KeyError.
# Message number 118 - KeyError.
# Message number 117 - KeyError.
# Message number 116 - KeyError.
# Message number 115 - KeyError.
# Message number 114 - KeyError.
# Message number 113 - KeyError.
# Message number 112 - KeyError.
# Message number 111 - KeyError.
# Message number 110 - KeyError.
# Message number 109 - KeyError.
# Message number 108 - KeyError.
# Message number 107 - KeyError.
# Message number 106 - KeyError.
# Message number 105 - KeyError.
# Message number 104 - KeyError.
# Message number 103 - KeyError.
# Message number 102 - KeyError.
# Message number 101 - KeyError.
# Message number 100 - KeyError.
# Message number 99 - KeyError.
# Message number 98 - KeyError.
# Message number 97 - KeyError.
# Message number 96 - KeyError.
# Message number 95 - KeyError.
# Message number 94 - KeyError.
# Message number 93 - KeyError.
# Message number 92 - KeyError.
# Message number 91 - KeyError.
# Message number 90 - KeyError.
# Message number 89 - KeyError.
# Message number 88 - KeyError.
# Message number 87 - KeyError.
# Message number 86 - KeyError.
# Message number 85 - KeyError.
# Message number 84 - KeyError.
# Message number 83 - KeyError.
# Message number 82 - KeyError.
# Message number 81 - KeyError.
# Message number 80 - KeyError.
# Message number 79 - KeyError.
# Message number 78 - KeyError.
# Message number 77 - KeyError.
# Message number 76 - KeyError.
# Message number 75 - KeyError.
# Message number 74 - KeyError.
# Message number 73 - KeyError.
# Message number 72 - KeyError.
# Message number 71 - KeyError.
# Message number 70 - KeyError.
# Message number 69 - KeyError.
# Message number 68 - KeyError.
# Message number 67 - KeyError.
# Message number 66 - KeyError.
# Message number 65 - KeyError.
# Message number 64 - KeyError.
# Message number 63 - KeyError.
# Message number 62 - KeyError.
# Message number 61 - KeyError.
# Message number 60 - KeyError.
# Message number 59 - KeyError.
# Message number 58 - KeyError.
# Message number 57 - KeyError.
# Message number 56 - KeyError.
# Message number 55 - KeyError.
# Message number 54 - KeyError.
# Message number 53 - KeyError.
# Message number 52 - KeyError.
# Message number 51 - KeyError.
# Message number 50 - KeyError.
# Message number 49 - KeyError.
# Message number 48 - KeyError.
# Message number 47 - KeyError.
# Message number 46 - KeyError.
# Message number 45 - KeyError.
# Message number 44 - KeyError.
# Message number 43 - KeyError.
# Message number 42 - KeyError.
# Message number 41 - KeyError.
# Message number 40 - KeyError.
# Message number 39 - KeyError.
# Message number 38 - KeyError.
# Message number 37 - KeyError.
# Message number 36 - KeyError.
# Message number 35 - KeyError.
# Message number 34 - KeyError.
# Message number 33 - KeyError.
# Message number 32 - KeyError.
# Message number 31 - KeyError.
# Message number 30 - KeyError.
# Message number 29 - KeyError.
# Message number 28 - KeyError.
# Message number 27 - KeyError.
# Message number 26 - KeyError.
# Message number 25 - KeyError.
# Message number 24 - KeyError.
# Message number 23 - KeyError.
# Message number 22 - KeyError.
# Message number 21 - KeyError.
# Message number 20 - KeyError.
# Message number 19 - KeyError.
# Message number 18 - KeyError.
# Message number 17 - KeyError.
# Message number 16 - KeyError.
# Message number 15 - KeyError.
# Message number 14 - KeyError.
# Message number 13 - KeyError.
# Message number 12 - KeyError.
# Message number 11 - KeyError.
# Message number 10 - KeyError.
# Message number 9 - KeyError.
# Message number 8 - KeyError.
# Message number 7 - KeyError.
# Message number 6 - KeyError.
# Message number 5 - KeyError.
# Message number 4 - KeyError.
# Message number 3 - KeyError.
# Message number 2 - KeyError.
# Message number 1 - KeyError.

# %%
# Save error_log for later reference.
with open(grp_name + '_err_log_' + 
        str(datetime.datetime.now())[2:16].replace(" ", "-").replace(":","") +
        '.log', mode='w') as logfile:
            print('This is the error log file from {}'.format(
                str(datetime.datetime.now())), file = logfile)
            print('Yahoo Group name {}.'.format(grp_name), file = logfile)
            for error_line in error_log:
                print(error_line, file = logfile)
logfile.close

# %%
# Define column list (With message body)
col_list = ['userId','authName','subject','Unix','Date',
            'msgId','preInTpc','nxtInTpc','preInTime',
            'nxtInTime','topicId','MsgsInTopic','msgRaw','msgTxt']

# Put structured data into a Pandas dataframe.
grand_df = DataFrame(grandlist, columns=col_list)

# %%
# Check results.
grand_df.head()
# Out:
#       userId              authName  \
# 0  581375493       Savage, Shannon
# 1  558034509              Sara Ash
# 2  190928695  Ray Tuttle (rtuttle)
# 3  569518549         Anthony Leger
# 4  578133796      Steward, David K
#
#                                              subject        Unix  \
# 0                  Filming and prop weapons policies  1541724012
# 1                                   CBD and Policies  1541456954
# 2  Holding students accountable for not respectin...  1541442992
# 3               RE: Student now not wanting a lawyer  1541438971
# 4                   Student now not wanting a lawyer  1541436488
#
#                   Date  msgId  preInTpc  nxtInTpc  preInTime  nxtInTime  \
# 0  2018-11-08 19:40:12  33102         0         0      33101          0
# 1  2018-11-05 17:29:14  33101         0         0      33100      33102
# 2  2018-11-05 13:36:32  33100         0         0      33099      33101
# 3  2018-11-05 12:29:31  33099     33098         0      33098      33100
# 4  2018-11-05 11:48:08  33098         0     33099      33097      33099
#
#    topicId  MsgsInTopic                                             msgRaw  \
# 0    33102            1  <div id="ygrps-yiv-1920241537">Hello all,<br/>...
# 1    33101            1  <div id="ygrps-yiv-79522852">Hello everyone,<b...
# 2    33100            1  <div id="ygrps-yiv-1523644933"><html>\n<head>\...
# 3    33098            2  <div id="ygrps-yiv-1607611912">Dave,<br/>\n<br...
# 4    33098            2  <div id="ygrps-yiv-1417733977">Have an interes...
#
#                                               msgTxt
# 0  Hello all,\n\nOur campus has recently had two ...
# 1  Hello everyone,\n\nI was wondering if you had ...
# 2  \n\n<!--\n#ygrps-yiv-1523644933  \n _filtered ...
# 3  Dave,\n\nI think it would depend on your polic...
# 4  Have an interesting twist to a case.\n\nStuden...

# %%
# Save to CSV
grand_df.to_csv(grp_name + '_messages.csv')

# %%
import re

def remove_unicode(uni_txt):
    # uni_txt.replace(u'\xa0', ' ').encode('utf-8')
    # uni_txt.replace(u'\u2019', "'").encode('utf-8')
    # uni_txt.replace(u'\u2022', '-').encode('utf-8')
    # try:
    #     print(uni_txt[1153])
    # except:
    #     print(uni_txt[:1])
    # uni_txt.replace(u'\u2022', '-').replace(u'\u2019', "'").replace(u'\u201c', '"').replace(u'\u201d', '"').replace(u'\u2014', '-').replace(u'\u2018', "'").replace(u'\u200b', ' ').replace(u'\u2013', '-').replace(u'\ufddf', ' ').replace(u'\ufffd', ' ').replace(u'\u2026', '...').replace(u'\u2028', '... ...').replace(u'\u263a', ' smile ').replace(u'\u1427', '-').replace(u'\u04cf', '|').replace(u'\uf0d8', '|?|').replace(u'\u200e', ' ').replace(u'\U0001f603', ' ').replace(u'\u2039', '<').replace(u'\u201a', "'").replace(u'\u2011', '-').replace(u'\u2002', ' ').replace(u'\u0335', '-').replace(u'\u2502', '|').replace(u'\u0160', 'S').replace(u'\u2015', '-').replace(u'\u2212', '-').replace(u'\u2010', ' ').replace(u'\ufffc', ' ').encode('latin-1')
    # pln_txt = uni_txt.encode('ascii', 'ignore')
    # pln_txt uni_txt.encode('latin-1', 'ignore')
    
    
    
    uni_txt = re.sub('[\u2022]', '-', uni_txt)
    uni_txt = re.sub('[\u201c]', '"', uni_txt)
    uni_txt = re.sub('[\u201d]', '"', uni_txt)
    uni_txt = re.sub('[\u2014]', '-', uni_txt)
    uni_txt = re.sub('[\u2018]', "'", uni_txt)
    uni_txt = re.sub('[\u200b]', "'", uni_txt)
    uni_txt = re.sub('[\u2013]', '-', uni_txt)
    uni_txt = re.sub('[\ufddf]', ' ', uni_txt)
    uni_txt = re.sub('[\ufffd]', ' ', uni_txt)
    uni_txt = re.sub('[\u2026]', "'", uni_txt)
    uni_txt = re.sub('[\u2028]', '... ...', uni_txt)
    uni_txt = re.sub('[\u263a]', ' smile ', uni_txt)
    uni_txt = re.sub('[\u1427]', '-', uni_txt)
    uni_txt = re.sub('[\u04cf]', "'", uni_txt)
    uni_txt = re.sub('[\uf0d8]', '|?|', uni_txt)
    uni_txt = re.sub('[\U0001f603]', ' ', uni_txt)
    uni_txt = re.sub('[\u2039]', '<', uni_txt)
    uni_txt = re.sub('[\u201a]', "'", uni_txt)
    uni_txt = re.sub('[\u2011]', '-', uni_txt)
    uni_txt = re.sub('[\u2002]', ' ', uni_txt)
    uni_txt = re.sub('[\u0335]', '-', uni_txt)
    uni_txt = re.sub('[\u2502]', '|', uni_txt)
    uni_txt = re.sub('[\u0160]', 'S', uni_txt)
    uni_txt = re.sub('[\u2015]', '-', uni_txt)
    uni_txt = re.sub('[\u2212]', '-', uni_txt)
    uni_txt = re.sub('[\u2010]', ' ', uni_txt)
    uni_txt = re.sub('[\ufffc]', ' ', uni_txt)
    uni_txt = re.sub('[\u200e]', ' ', uni_txt)
    uni_txt = re.sub('[\uf050]', ' ', uni_txt)
    uni_txt = re.sub('[\u2027]', '-', uni_txt)
    uni_txt = re.sub('[\u20AC]', ' ', uni_txt)
    uni_txt = re.sub('[\u2122]', ' ', uni_txt)
    uni_txt = re.sub('[\u02dc]', '~', uni_txt)
    uni_txt = re.sub('[\u0153]', 'oe', uni_txt)
    uni_txt = re.sub('[\ufb01]', 'fi', uni_txt)
    uni_txt = re.sub('[\u201e]', '"', uni_txt)
    uni_txt = re.sub('[\u0192]', 'f', uni_txt)
    
    uni_txt = re.sub('[\u25a1]', ' ', uni_txt)
    uni_txt = re.sub('[\u25cf]', '-', uni_txt)
    uni_txt = re.sub('[\uf097]', ' ', uni_txt)
    uni_txt = re.sub('[\u25aa]', '-', uni_txt)
    uni_txt = re.sub('[\u2030]', '%', uni_txt)
    uni_txt = re.sub('[\u25ba]', '>', uni_txt)
    
    uni_txt = re.sub('[\uF1FF]', '', uni_txt)
    uni_txt = re.sub('[\u3050]', '', uni_txt)
    uni_txt = re.sub('[\u98B5]', '', uni_txt)
    uni_txt = re.sub('[\u11CF]', '', uni_txt)
    uni_txt = re.sub('[\u82BB]', '', uni_txt)
    uni_txt = re.sub('[\uAA00]', '', uni_txt)
    uni_txt = re.sub('[\uBD00]', '', uni_txt)
    
    uni_txt = re.sub('[\u0bce]', '', uni_txt)
    uni_txt = re.sub('[\uf022]', '', uni_txt)
    
    uni_txt = re.sub('[\u221d]', '', uni_txt)
    uni_txt = re.sub('[\u2329]', '<', uni_txt)
    uni_txt = re.sub('[\u232A]', '>', uni_txt)
    uni_txt = re.sub('[\u002D]', '-', uni_txt)
    uni_txt = re.sub('[\u03c0]', 'pi', uni_txt)
    uni_txt = re.sub('[\uf0a7]', '', uni_txt)
    
    uni_txt = re.sub('[\U0010003e]', '', uni_txt)
    uni_txt = re.sub('[\u2282]', '', uni_txt)
    uni_txt = re.sub('[\uf0a7]', '', uni_txt)
    uni_txt = re.sub('[\uf0a7]', '', uni_txt)
    uni_txt = re.sub('[\uf0a7]', '', uni_txt)
    uni_txt = re.sub('[\uf0a7]', '', uni_txt)
    
    uni_txt = re.sub('[\u2019]', 'LOOK HERE REGEXP', uni_txt)
    uni_txt.replace(u'\u2019', 'LOOK HERE REPLACE').encode('latin-1')
    
    # uni_txt = re.sub('[t]', 'THIS IS DUMB', uni_txt)
    
    # uni_txt = re.sub('[’]', 'LOOK HERE REGEXP 222', uni_txt)
    # uni_txt.replace(u'’', 'LOOK HERE REPLACE 222').encode('latin-1')
    
    # pln_txt = uni_txt
    # return(uni_txt)
    # return('bye bye bye')
    return(uni_txt)

grand_df['msgRaw'] = grand_df['msgRaw'].apply(remove_unicode)
grand_df['msgTxt'] = grand_df['msgTxt'].apply(remove_unicode)
grand_df['subject'] = grand_df['subject'].apply(remove_unicode)

def print_position(qtext):
    if len(qtext) > 11 + 1:
        if qtext[11] == u'\u201c':
            print(qtext[11:21])

def add_lots(numtoadd):
    highernum = numtoadd + 500
    return(highernum)

# grand_df['MsgsInTopic'] = grand_df['MsgsInTopic'].apply(add_lots)

# print(add_lots(50))
            
# print(remove_unicode('hello hello hello'))
            
# grand_df['msgRaw'].apply(print_position)

# Save to Stata
# Problems on this. See: https://github.com/pandas-dev/pandas/issues/16450
grand_df.to_stata(grp_name + '_messages.dta', version=117, convert_strl=['subject','msgRaw','msgTxt'])
df = grand_df
df[['subject']].to_stata('Stata_file_works.dta', version=117, convert_strl=['subject'])
# grand_df.head()

# %%
# Save to Excel
writer = pd.ExcelWriter(grp_name + '_messages.xlsx', engine='xlsxwriter')
grand_df.to_excel(writer, sheet_name='Sheet1')
writer.save()

# %%
import re

# re.sub('[es]', '', 'test')

re.sub('[\u2019]', '', u'hello \u2022 \u2022 \u2022world \u2019 \u2019 \u2019')

# %%
'hello'.encode()

# %%
u = u'hello \u2022 \u2022 \u2022world ```'

u

# %%
u.replace(u'\u2022', '-').replace(u'\u2019', "'").encode('latin-1')

# %%
print('hello world'[100])

# %%
len('hello')

# %%
re.sub('[’]', 'LOOK HERE REGEXP 222', '___ ’ ___')

# %%
exfile = pd.read_stata('http://www.stata-press.com/data/r15/auto2.dta')
exfile.head(n=1)
# Out:
#           make  price  mpg    rep78  headroom  trunk  weight  length  turn  \
# 0  AMC Concord   4099   22  Average       2.5     11    2930     186    40
#
#    displacement  gear_ratio   foreign
# 0           121        3.58  Domestic

# %%
def make_longer(shorter):
    longer = shorter * 100000
    return(longer)
    
exfile['make'] = exfile['make'].apply(make_longer)

# %%
exfile.head(n=1)
# Out:
#                                                 make  price  mpg    rep78  \
# 0  AMC ConcordAMC ConcordAMC ConcordAMC ConcordAM...   4099   22  Average
#
#    headroom  trunk  weight  length  turn  displacement  gear_ratio   foreign
# 0       2.5     11    2930     186    40           121        3.58  Domestic

# %%
exfile.to_stata('Stata_file_auto.dta', version=117, convert_strl=['make'])
